# %%
import pandas as pd 

data = pd.read_csv("Data/KR_youtube_trending_data.csv", index_col = 0)
# print(data.head())

# 인기 동영상 제작 횟수가 많은 상위 10개명을 출력(날짜 기준, 중복 포함)

print(data.columns)
# Out:
#                                                         title  \
# video_id
# uq5LClQN3cE                                       안녕하세요 보겸입니다
# I-ZbZCHsHD0                                부락토스의 계획 [총몇명 프리퀄]
# 9d7jNUjBoss                                   평생 반성하면서 살겠습니다.
# 3pI_L3-sMVg                              안녕하세요 꽈뚜룹입니다.
# zrsBjYukE8s  박진영 (J.Y. Park) When We Disco (Duet with 선미) M/V
#
#                       publishedAt                 channelId  \
# video_id
# uq5LClQN3cE  2020-08-09T09:32:48Z  UCu9BCtGIEr73LXZsKmoujKw
# I-ZbZCHsHD0  2020-08-12T09:00:08Z  UCRuSxVu4iqTK5kCh90ntAgA
# 9d7jNUjBoss  2020-08-10T09:54:13Z  UCMVC92EOs9yDJG5JS-CMesQ
# 3pI_L3-sMVg  2020-08-11T15:00:58Z  UCkQCwnkQfgSuPTTnw_Y7v7w
# zrsBjYukE8s  2020-08-11T09:00:13Z  UCaO6TYtlC8U5ttz62hTrZgg
#
#                   channelTitle  categoryId         trending_date  \
# video_id
# uq5LClQN3cE              보겸 BK          24  2020-08-12T00:00:00Z
# ...
